# %%
#import libraries 
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Activation, Add, MaxPooling2D, Conv2D, Flatten, BatchNormalization, MaxPool2D
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 3
#       1 #import libraries
#       2 import tensorflow as tf
# ----> 3 from tensorflow.keras.layers import Dense, Dropout, Activation, Add, MaxPooling2D, Conv2D, Flatten, BatchNormalization, MaxPool2D
#       4 from tensorflow.keras.models import Sequential
#       5 from tensorflow.keras import layers
#
# ModuleNotFoundError: No module named 'tensorflow.keras'

# %%
#import train data
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    "./images/", labels='inferred', label_mode='int', class_names=None,
    color_mode='rgb', batch_size=32, image_size=(50, 50), shuffle=True, seed=123,
    validation_split=0.2, subset="training"
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Kinsh\Desktop\Project\Medini\sign_langauge_translator\ml_env\lib\site-packages\tensorflow\python\util\lazy_loader.py:147, in _initialize(self)
#     146   self._initialize()
# --> 147 if self._keras_version == "keras_3":
#     148   if (self._mode == "v1" and
#     149       not self._submodule and
#     150       item.startswith("compat.v1.")):
#
# File c:\Users\Kinsh\Desktop\Project\Medini\sign_langauge_translator\ml_env\lib\site-packages\keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#
# File c:\Users\Kinsh\Desktop\Project\Medini\sign_langauge_translator\ml_env\lib\site-packages\keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
# ...
